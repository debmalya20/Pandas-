# %%
import pandas as pd
import numpy as np

# %%
dl=pd.read_csv(r'Countries.csv')

# %%
dl
# Out:
#                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# ...

# %%
dl.shape #This is for knowing the shape of the datalist

# %%
dl.info()

# %%
dl.describe()

# %%
dl[dl["population"]==dl["population"].max()] ['capital_city']#This is how we can get the max

# %%
dl[dl['population'] == dl['population'].max()]['capital_city']

# %%
dl[dl["population"]==dl["population"].min()]["country"]

# %%
dl[dl["population"]==dl["population"].min()]['capital_city']
# Out:
# 179    Funafuti
# Name: capital_city, dtype: object

# %%
dl.head()
# Out:
#        country                             country_long        currency  \
# 0  Afghanistan             Islamic State of Afghanistan  Afghan afghani
# 1      Albania                      Republic of Albania    Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria  Algerian dinar
# 3      Andorra                  Principality of Andorra            Euro
# 4       Angola              People's Republic of Angola  Angolan kwanza
#
#        capital_city           region continent   demonym  latitude  longitude  \
# 0             Kabul    Southern Asia      Asia    Afghan      33.0       65.0
# 1            Tirana  Southern Europe    Europe  Albanian      41.0       20.0
# 2           Algiers  Northern Africa    Africa  Algerian      28.0        3.0
# 3  Andorra la Vella  Southern Europe    Europe  Andorran      42.5        1.5
# 4            Luanda    Middle Africa    Africa   Angolan     -12.5       18.5
#
# ...

# %%
dl
# Out:
#                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# ...

# %%
dl.sort_values(by='democracy_score',ascending=False,inplace = True) # this helps me sorting of data and ascendinfg false helps to maintain large to small

# %%
dl
# Out:
#                             country                    country_long  \
# 127                          Norway               Kingdom of Norway
# 74                          Iceland             Republic of Iceland
# 164                          Sweden               Kingdom of Sweden
# 122                     New Zealand                     New Zealand
# 46                          Denmark              Kingdom of Denmark
# ..                              ...                             ...
# 154                         Somalia      Somali Democratic Republic
# 161  St. Vincent and the Grenadines  St. Vincent and the Grenadines
# 160                       St. Lucia                       St. Lucia
# 159             St. Kitts and Nevis             St. Kitts and Nevis
# 97                    Liechtenstein   Principality of Liechtenstein
#
#                   currency capital_city                     region continent  \
# ...

# %%
dl['country'].head()
# Out:
# 127         Norway
# 74         Iceland
# 164         Sweden
# 122    New Zealand
# 46         Denmark
# Name: country, dtype: object

# %%
#total countrys are there?
dl['region'].value_counts().count() # this function helps to count the values inside a calumn
# Out:
# np.int64(22)

# %%
dl[dl['region'] == "Eastern Europe"][ 'country']
# Out:
# 14             Belarus
# 24            Bulgaria
# 43      Czech Republic
# 73             Hungary
# 111            Moldova
# 136             Poland
# 139            Romania
# 140             Russia
# 151    Slovak Republic
# 181            Ukraine
# Name: country, dtype: object
